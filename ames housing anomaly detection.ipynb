# %% [markdown]
# # Import the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from datetime import datetime, date
from scipy import stats
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load the dataset

# %%
df = pd.read_csv('ames_housing_preprocessed_feat_sel.csv')
df.shape
# Out:
# (1460, 57)

# %%
df.head()
# Out:
#    1stFlrSF  3SsnPorch  BldgType  BsmtExposure  BsmtFinSF1  BsmtFinSF2  \
# 0       856          0         0             3         706           0
# 1      1262          0         0             1         978           0
# 2       920          0         0             2         486           0
# 3       961          0         0             3         216           0
# 4      1145          0         0             0         655           0
#
#    BsmtFinType1  BsmtFullBath  BsmtHalfBath  BsmtQual     ...      \
# 0             2             1             0         2     ...
# 1             0             0             1         2     ...
# 2             2             1             0         2     ...
# 3             0             1             0         4     ...
# 4             2             1             0         2     ...
#
#    SaleCondition  ScreenPorch  Street  TotRmsAbvGrd  TotalBsmtSF  WoodDeckSF  \
# 0              4            0       1             8          856           0
# 1              4            0       1             6         1262         298
# 2              4            0       1             6          920           0
# 3              0            0       1             7          756           0
# 4              4            0       1             9         1145         192
#
#    YearBuilt  YearRemodAdd  YrSold  Sale Price
# 0       2003          2003       2   12.247699
# 1       1976          1976       1   12.109016
# 2       2001          2002       2   12.317171
# 3       1915          1970       0   11.849405
# 4       2000          2000       2   12.429220
#
# [5 rows x 57 columns]

# %% [markdown]
# # Normalize the dataset

# %%
#normalize the dataset
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_norm = pd.DataFrame(scaler.fit_transform(df))

df_norm.columns = df.columns
df_norm.head()
# Out:
#    1stFlrSF  3SsnPorch  BldgType  BsmtExposure  BsmtFinSF1  BsmtFinSF2  \
# 0 -0.793434  -0.116339 -0.411691      0.591905    0.575425   -0.288653
# 1  0.257140  -0.116339 -0.411691     -1.124444    1.171992   -0.288653
# 2 -0.627826  -0.116339 -0.411691     -0.266269    0.092907   -0.288653
# 3 -0.521734  -0.116339 -0.411691      0.591905   -0.499274   -0.288653
# 4 -0.045611  -0.116339 -0.411691     -1.982619    0.463568   -0.288653
#
#    BsmtFinType1  BsmtFullBath  BsmtHalfBath  BsmtQual     ...      \
# 0     -0.510942      1.107810     -0.241061 -0.566939     ...
# 1     -1.399536     -0.819964      3.948809 -0.566939     ...
# 2     -0.510942      1.107810     -0.241061 -0.566939     ...
# 3     -1.399536      1.107810     -0.241061  0.997770     ...
# 4     -0.510942      1.107810     -0.241061 -0.566939     ...
#
#    SaleCondition  ScreenPorch    Street  TotRmsAbvGrd  TotalBsmtSF  \
# 0       0.208502    -0.270208  0.064238      0.912210    -0.459303
# 1       0.208502    -0.270208  0.064238     -0.318683     0.466465
# 2       0.208502    -0.270208  0.064238     -0.318683    -0.313369
# 3      -3.426284    -0.270208  0.064238      0.296763    -0.687324
# 4       0.208502    -0.270208  0.064238      1.527656     0.199680
#
#    WoodDeckSF  YearBuilt  YearRemodAdd    YrSold  Sale Price
# 0   -0.752176   1.050994      0.878668  0.138777    0.560067
# 1    1.626195   0.156734     -0.429577 -0.614439    0.212763
# 2   -0.752176   0.984752      0.830215  0.138777    0.734046
# 3   -0.752176  -1.863632     -0.720298 -1.367655   -0.437383
# 4    0.780197   0.951632      0.733308  0.138777    1.014651
#
# [5 rows x 57 columns]

# %% [markdown]
# # Use PYOD to detect Anomaly

# %%
from pyod.models.iforest import IForest
random_state = np.random.RandomState(42)
outliers_fraction = 0.05
classifiers = {
        'Isolation Forest': IForest(contamination=outliers_fraction,random_state=random_state)
}

# %%
for i, (clf_name, clf) in enumerate(classifiers.items()):
    clf.fit(df_norm)
    # predict raw anomaly score
    scores_pred = clf.decision_function(df_norm) * -1
        
    # prediction of a datapoint category outlier or inlier
    y_pred = clf.predict(df_norm)
    n_inliers = len(y_pred) - np.count_nonzero(y_pred)
    n_outliers = np.count_nonzero(y_pred == 1)
    plt.figure(figsize=(10, 10))
    
    # copy of dataframe
    dfx = df_norm.copy(deep=True)
    dfx['outlier'] = y_pred.tolist()
         
    print('OUTLIERS : ',n_outliers,'INLIERS : ',n_inliers, clf_name)
# Out:
# OUTLIERS :  73 INLIERS :  1387 Isolation Forest

# %%
dfoo = pd.DataFrame(df)
dfoo['outlier'] = y_pred.tolist()
dfoo.head()
# Out:
#    1stFlrSF  3SsnPorch  BldgType  BsmtExposure  BsmtFinSF1  BsmtFinSF2  \
# 0       856          0         0             3         706           0
# 1      1262          0         0             1         978           0
# 2       920          0         0             2         486           0
# 3       961          0         0             3         216           0
# 4      1145          0         0             0         655           0
#
#    BsmtFinType1  BsmtFullBath  BsmtHalfBath  BsmtQual   ...     ScreenPorch  \
# 0             2             1             0         2   ...               0
# 1             0             0             1         2   ...               0
# 2             2             1             0         2   ...               0
# 3             0             1             0         4   ...               0
# 4             2             1             0         2   ...               0
#
#    Street  TotRmsAbvGrd  TotalBsmtSF  WoodDeckSF  YearBuilt  YearRemodAdd  \
# 0       1             8          856           0       2003          2003
# 1       1             6         1262         298       1976          1976
# 2       1             6          920           0       2001          2002
# 3       1             7          756           0       1915          1970
# 4       1             9         1145         192       2000          2000
#
#    YrSold  Sale Price  outlier
# 0       2   12.247699        0
# 1       1   12.109016        0
# 2       2   12.317171        0
# 3       0   11.849405        0
# 4       2   12.429220        0
#
# [5 rows x 58 columns]

# %%
dfoo[dfoo['outlier'] == 1].head(25)
# Out:
#      1stFlrSF  3SsnPorch  BldgType  BsmtExposure  BsmtFinSF1  BsmtFinSF2  \
# 39       1152          0         2             4           0           0
# 53       1842          0         0             1        1810           0
# 58       1426          0         0             1           0           0
# 88       1013          0         0             3           0           0
# 108       997          0         0             3           0           0
# 178      2234          0         0             3        1904           0
# 185      1518          0         0             2           0           0
# 197      1360          0         0             3        1036         184
# 249      1444          0         0             1         697           0
# 250      1306          0         0             3           0           0
# 291       936          0         1             3         210           0
# 307      1035          0         0             3           0           0
# 335      1619          0         1             1        1249         147
# 375       904          0         0             1         350           0
# 386       658          0         0             3           0           0
# 417      1370          0         0             3        1128           0
# 440      2402          0         0             1        1767         539
# 495       720          0         0             3         495           0
# 520       694          0         1             4           0           0
# 523      3138          0         0             1        2260           0
# 528       605          0         0             2         348           0
# 533       334          0         0             4           0           0
# 583      1521          0         0             3           0           0
# 614       630          0         4             0         150         480
# 630      1089          0         0             3           0           0
#
#      BsmtFinType1  BsmtFullBath  BsmtHalfBath  BsmtQual   ...     ScreenPorch  \
# 39              4             0             0         3   ...               0
# 53              2             2             0         0   ...               0
# 58              6             0             0         0   ...               0
# 88              6             0             0         4   ...               0
# 108             6             0             0         4   ...               0
# 178             2             1             0         0   ...               0
# 185             6             0             0         4   ...             410
# 197             2             1             1         4   ...               0
# 249             5             0             1         2   ...               0
# 250             6             0             0         4   ...               0
# 291             5             1             0         4   ...               0
# 307             6             0             0         4   ...               0
# 335             0             2             0         4   ...               0
# 375             1             1             0         1   ...               0
# 386             6             0             0         4   ...               0
# 417             1             1             0         2   ...               0
# 440             2             1             0         0   ...             170
# 495             5             0             0         4   ...               0
# 520             4             0             0         3   ...               0
# 523             2             1             0         0   ...               0
# 528             0             1             0         4   ...               0
# 533             4             0             0         3   ...               0
# 583             6             0             0         4   ...               0
# 614             3             1             0         2   ...               0
# 630             6             0             0         1   ...               0
#
#      Street  TotRmsAbvGrd  TotalBsmtSF  WoodDeckSF  YearBuilt  YearRemodAdd  \
# 39        1             6            0           0       1955          1955
# 53        1             5         1842         857       1981          1987
# 58        1            10         1410         192       2006          2006
# 88        1             6         1013           0       1915          1982
# 108       1             7          793           0       1919          2005
# 178       1             9         2216           0       2008          2009
# 185       1            12         1107           0       1892          1993
# 197       1             8         1360           0       1918          1990
# 249       1             7         1444           0       1958          2006
# 250       1             6          728         263       1940          1966
# 291       1             9          780           0       1912          2000
# 307       1             6          319           0       1920          1950
# 335       0             7         1499         670       1965          1965
# 375       1             4          683           0       1922          1950
# 386       1             8          658           0       1910          1996
# 417       1            10         1370           0       1918          1950
# 440       1            10         3094           0       2008          2008
# 495       1             4          720           0       1920          1950
# 520       1             7            0         220       1900          2000
# 523       1            11         3138         208       2007          2008
# 528       1             5          528           0       1920          2002
# 533       1             2            0           0       1946          1950
# 583       1             9         1237         105       1893          2000
# 614       1             3          630          96       1972          1972
# 630       1             8          636           0       1880          1991
#
#      YrSold  Sale Price  outlier
# 39        2   11.314487        1
# 53        0   12.861001        1
# 58        0   12.991756        1
# 88        3   11.350418        1
# 108       1   11.652696        1
# 178       3   13.126033        1
# 185       0   13.071072        1
# 197       0   12.367345        1
# 249       1   12.531776        1
# 250       4   11.245059        1
# 291       2   11.819682        1
# 307       2   11.402005        1
# 335       2   12.341263        1
# 375       3   11.018646        1
# 386       0   11.302217        1
# 417       1   12.384223        1
# 440       3   13.226725        1
# 495       3   10.460271        1
# 520       2   11.573559        1
# 523       1   12.126764        1
# 528       1   11.362114        1
# 533       1   10.579005        1
# 583       2   12.691584        1
# 614       4   11.231901        1
# 630       0   11.728045        1
#
# [25 rows x 58 columns]

# %%
dfx.head()
# Out:
#    1stFlrSF  3SsnPorch  BldgType  BsmtExposure  BsmtFinSF1  BsmtFinSF2  \
# 0 -0.793434  -0.116339 -0.411691      0.591905    0.575425   -0.288653
# 1  0.257140  -0.116339 -0.411691     -1.124444    1.171992   -0.288653
# 2 -0.627826  -0.116339 -0.411691     -0.266269    0.092907   -0.288653
# 3 -0.521734  -0.116339 -0.411691      0.591905   -0.499274   -0.288653
# 4 -0.045611  -0.116339 -0.411691     -1.982619    0.463568   -0.288653
#
#    BsmtFinType1  BsmtFullBath  BsmtHalfBath  BsmtQual   ...     ScreenPorch  \
# 0     -0.510942      1.107810     -0.241061 -0.566939   ...       -0.270208
# 1     -1.399536     -0.819964      3.948809 -0.566939   ...       -0.270208
# 2     -0.510942      1.107810     -0.241061 -0.566939   ...       -0.270208
# 3     -1.399536      1.107810     -0.241061  0.997770   ...       -0.270208
# 4     -0.510942      1.107810     -0.241061 -0.566939   ...       -0.270208
#
#      Street  TotRmsAbvGrd  TotalBsmtSF  WoodDeckSF  YearBuilt  YearRemodAdd  \
# 0  0.064238      0.912210    -0.459303   -0.752176   1.050994      0.878668
# 1  0.064238     -0.318683     0.466465    1.626195   0.156734     -0.429577
# 2  0.064238     -0.318683    -0.313369   -0.752176   0.984752      0.830215
# 3  0.064238      0.296763    -0.687324   -0.752176  -1.863632     -0.720298
# 4  0.064238      1.527656     0.199680    0.780197   0.951632      0.733308
#
#      YrSold  Sale Price  outlier
# 0  0.138777    0.560067        0
# 1 -0.614439    0.212763        0
# 2  0.138777    0.734046        0
# 3 -1.367655   -0.437383        0
# 4  0.138777    1.014651        0
#
# [5 rows x 58 columns]

# %%
dfx.to_csv('ames_data_with_feat_sel_outlier_status.csv', index=False)
